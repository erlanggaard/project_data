# %% [markdown]
# ### Read The Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/retail_raw_test.csv", low_memory=False)

# %%
df_copy = df.copy()

# %%
df.head()
# Out:
#    order_id    order_date customer_id           city     province    brand  \
# 0   1730350  Dec 11, 2019      '13447      Surakarta  Jawa Tengah  BRAND_F
# 1   1677490  Jul 31, 2019          '0            NaN          NaN  BRAND_F
# 2   1704211  Oct 18, 2019      '16128  Jakarta Pusat  DKI Jakarta  BRAND_H
# 3   1679695  Aug 07, 2019      '16225     Yogyakarta   Yogyakarta  BRAND_H
# 4   1679080  Aug 05, 2019          '0            NaN          NaN  BRAND_E
#
#   quantity item_price  product_value
# 0      '24    '113000         1374.0
# 1       '1   '1164000         1370.0
# 2      '12    '747000         1679.0
# 3       '6    '590000         1708.0
# 4       '2    '740000         1201.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       5000 non-null   int64
#  1   order_date     5000 non-null   object
#  2   customer_id    5000 non-null   object
#  3   city           3802 non-null   object
#  4   province       3802 non-null   object
#  5   brand          4995 non-null   object
#  6   quantity       5000 non-null   object
#  7   item_price     5000 non-null   object
#  8   product_value  4995 non-null   float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 351.7+ KB

# %% [markdown]
# ### Change Data Type
# Mengubah kolom yang memiliki tipe data tidak sesuai

# %%
df["customer_id"] = df["customer_id"].apply(lambda x: x.split("'")[1]).astype("int64")

# %%
df["quantity"] = df["quantity"].apply(lambda x: x.split("'")[1]).astype("int64")

# %%
df["item_price"] = df["item_price"].apply(lambda x: x.split("'")[1]).astype("int64")

# %%
df.dtypes
# Out:
# order_id           int64
# order_date        object
# customer_id        int64
# city              object
# province          object
# brand             object
# quantity           int64
# item_price         int64
# product_value    float64
# dtype: object

# %% [markdown]
# ### Transform "product_value"
# transform product_value supaya bentuknya seragam dengan format PXXXX, assign ke kolom baru "product_id", dan drop kolom "product_value", jika terdapat nan gantilah dengan "unknown".

# %%
import math

# %%
def impute_product_value(val):
    if math.isnan(val):
        return "unknown"
    else:
        return "P" + '{:0>4}'.format(str(val).split('.')[0])

# %%
df["product_id"] = df["product_value"].apply(lambda x: impute_product_value(x))

# %%
df["product_value"]
# Out:
# 0       1374.0
# 1       1370.0
# 2       1679.0
# 3       1708.0
# 4       1201.0
#          ...
# 4995     449.0
# 4996    1685.0
# 4997    3206.0
# 4998    4126.0
# 4999    1890.0
# Name: product_value, Length: 5000, dtype: float64

# %%
df.drop(["product_value"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    order_id    order_date  customer_id           city     province    brand  \
# 0   1730350  Dec 11, 2019        13447      Surakarta  Jawa Tengah  BRAND_F
# 1   1677490  Jul 31, 2019            0            NaN          NaN  BRAND_F
# 2   1704211  Oct 18, 2019        16128  Jakarta Pusat  DKI Jakarta  BRAND_H
# 3   1679695  Aug 07, 2019        16225     Yogyakarta   Yogyakarta  BRAND_H
# 4   1679080  Aug 05, 2019            0            NaN          NaN  BRAND_E
#
#    quantity  item_price product_id
# 0        24      113000      P1374
# 1         1     1164000      P1370
# 2        12      747000      P1679
# 3         6      590000      P1708
# 4         2      740000      P1201

# %% [markdown]
# ### Transform "order_date"
# trasnform order_date menjadi value dengan format YYYY-mm-dd

# %%
df["order_date"]
# Out:
# 0       Dec 11, 2019
# 1       Jul 31, 2019
# 2       Oct 18, 2019
# 3       Aug 07, 2019
# 4       Aug 05, 2019
#             ...
# 4995    Jan 08, 2019
# 4996    Dec 03, 2019
# 4997    Nov 13, 2019
# 4998    Jul 03, 2019
# 4999    Nov 26, 2019
# Name: order_date, Length: 5000, dtype: object

# %%
months_dict = {
    "Jan" : "01",
    "Feb" : "02",
    "Mar" : "03",
    "Apr" : "04",
    "May" : "05",
    "Jun" : "06",
    "Jul" : "07",
    "Aug" : "08",
    "Sep" : "09",
    "Oct" : "10",
    "Nov" : "11",
    "Dec" : "12",
}

# %%
df["order_date"] = pd.to_datetime(df["order_date"].apply(lambda x: str(x)[-4:] + "-" + months_dict[str(x)[:3]] + "-" + str(x)[4:7]))

# %%
df.head()
# Out:
#                                                                                  brand  \
# city/province          order_date customer_id customer_id order_id product_id
# Banda Aceh/Aceh        2019-04-17 12818       12818       1642480  P1936       BRAND_K
#                        2019-11-12 12360       12360       1715116  P0758       BRAND_C
#                                                                    P3042       BRAND_R
#                        2019-12-09 12374       12374       1729036  P1660       BRAND_G
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628       BRAND_C
#
#                                                                                quantity  \
# city/province          order_date customer_id customer_id order_id product_id
# Banda Aceh/Aceh        2019-04-17 12818       12818       1642480  P1936             24
#                        2019-11-12 12360       12360       1715116  P0758              8
#                                                                    P3042             12
#                        2019-12-09 12374       12374       1729036  P1660              4
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628             12
#
#                                                                                item_price  \
# city/province          order_date customer_id customer_id order_id product_id
# Banda Aceh/Aceh        2019-04-17 12818       12818       1642480  P1936           450000
#                        2019-11-12 12360       12360       1715116  P0758           695000
#                                                                    P3042           310000
#                        2019-12-09 12374       12374       1729036  P1660          2795000
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628           695000
#
#                                                                                total_price
# city/province          order_date customer_id customer_id order_id product_id
# Banda Aceh/Aceh        2019-04-17 12818       12818       1642480  P1936          10800000
#                        2019-11-12 12360       12360       1715116  P0758           5560000
#                                                                    P3042           3720000
#                        2019-12-09 12374       12374       1729036  P1660          11180000
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628           8340000

# %% [markdown]
# ### Missing Values
# Cek data yang hilang dari tiap kolom dan kemudian isi missing value:
# <li> di "brand" dengan "no_brand"
# <li> cek bagaimana missing value di city & province isi dengan "unknown"

# %%
df.isna().sum()
# Out:
# order_id          0
# order_date        0
# customer_id       0
# city           1198
# province       1198
# brand             5
# quantity          0
# item_price        0
# product_id        0
# dtype: int64

# %%
df[["city", "province"]] = df[["city", "province"]].fillna("Unknown")

# %%
df["brand"] = df["brand"].fillna("no_brand")

# %%
df.isna().sum()
# Out:
# order_id       0
# order_date     0
# customer_id    0
# city           0
# province       0
# brand          0
# quantity       0
# item_price     0
# product_id     0
# dtype: int64

# %% [markdown]
# ### Membuat column city/province dari gabungan city & province

# %%
df["city/province"] = df["city"] + "/" + df["province"]

# %%
df.head()
# Out:
#    order_id order_date  customer_id           city     province    brand  \
# 0   1730350 2019-12-11        13447      Surakarta  Jawa Tengah  BRAND_F
# 1   1677490 2019-07-31            0        Unknown      Unknown  BRAND_F
# 2   1704211 2019-10-18        16128  Jakarta Pusat  DKI Jakarta  BRAND_H
# 3   1679695 2019-08-07        16225     Yogyakarta   Yogyakarta  BRAND_H
# 4   1679080 2019-08-05            0        Unknown      Unknown  BRAND_E
#
#    quantity  item_price product_id              city/province
# 0        24      113000      P1374      Surakarta/Jawa Tengah
# 1         1     1164000      P1370            Unknown/Unknown
# 2        12      747000      P1679  Jakarta Pusat/DKI Jakarta
# 3         6      590000      P1708      Yogyakarta/Yogyakarta
# 4         2      740000      P1201            Unknown/Unknown

# %%
df.drop(columns=["city", "province"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    order_id order_date  customer_id    brand  quantity  item_price product_id  \
# 0   1730350 2019-12-11        13447  BRAND_F        24      113000      P1374
# 1   1677490 2019-07-31            0  BRAND_F         1     1164000      P1370
# 2   1704211 2019-10-18        16128  BRAND_H        12      747000      P1679
# 3   1679695 2019-08-07        16225  BRAND_H         6      590000      P1708
# 4   1679080 2019-08-05            0  BRAND_E         2      740000      P1201
#
#                city/province
# 0      Surakarta/Jawa Tengah
# 1            Unknown/Unknown
# 2  Jakarta Pusat/DKI Jakarta
# 3      Yogyakarta/Yogyakarta
# 4            Unknown/Unknown

# %%
df["city/province"] = df["city/province"].replace(["Unknown/Unknown"], "Unknown")

# %%
df.head()
# Out:
#    order_id order_date  customer_id    brand  quantity  item_price product_id  \
# 0   1730350 2019-12-11        13447  BRAND_F        24      113000      P1374
# 1   1677490 2019-07-31            0  BRAND_F         1     1164000      P1370
# 2   1704211 2019-10-18        16128  BRAND_H        12      747000      P1679
# 3   1679695 2019-08-07        16225  BRAND_H         6      590000      P1708
# 4   1679080 2019-08-05            0  BRAND_E         2      740000      P1201
#
#                city/province
# 0      Surakarta/Jawa Tengah
# 1                    Unknown
# 2  Jakarta Pusat/DKI Jakarta
# 3      Yogyakarta/Yogyakarta
# 4                    Unknown

# %% [markdown]
# ### Creating Hierachical Index
# membuat index berdasarkan city_provice, order_date, customer_id, order_id, product_id (cek index)

# %%
df = df.set_index(["city/province", "order_date", "customer_id", "customer_id", "order_id", "product_id"])

# %%
df = df.sort_index()

# %%
df.head()
# Out:
#                                                                                  brand  \
# city/province          order_date customer_id customer_id order_id product_id
# Banda Aceh/Aceh        2019-04-17 12818       12818       1642480  P1936       BRAND_K
#                        2019-11-12 12360       12360       1715116  P0758       BRAND_C
#                                                                    P3042       BRAND_R
#                        2019-12-09 12374       12374       1729036  P1660       BRAND_G
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628       BRAND_C
#
#                                                                                quantity  \
# city/province          order_date customer_id customer_id order_id product_id
# Banda Aceh/Aceh        2019-04-17 12818       12818       1642480  P1936             24
#                        2019-11-12 12360       12360       1715116  P0758              8
#                                                                    P3042             12
#                        2019-12-09 12374       12374       1729036  P1660              4
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628             12
#
#                                                                                item_price
# city/province          order_date customer_id customer_id order_id product_id
# Banda Aceh/Aceh        2019-04-17 12818       12818       1642480  P1936           450000
#                        2019-11-12 12360       12360       1715116  P0758           695000
#                                                                    P3042           310000
#                        2019-12-09 12374       12374       1729036  P1660          2795000
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628           695000

# %% [markdown]
# ### Create "total_price" Columns
# membuat kolom "total_price" sebagai hasil perkalian quantity dengan item_price

# %%
df["total_price"] = df["quantity"] * df["item_price"]

# %%
df.head()
# Out:
#                                                                                  brand  \
# city/province          order_date customer_id customer_id order_id product_id
# Banda Aceh/Aceh        2019-04-17 12818       12818       1642480  P1936       BRAND_K
#                        2019-11-12 12360       12360       1715116  P0758       BRAND_C
#                                                                    P3042       BRAND_R
#                        2019-12-09 12374       12374       1729036  P1660       BRAND_G
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628       BRAND_C
#
#                                                                                quantity  \
# city/province          order_date customer_id customer_id order_id product_id
# Banda Aceh/Aceh        2019-04-17 12818       12818       1642480  P1936             24
#                        2019-11-12 12360       12360       1715116  P0758              8
#                                                                    P3042             12
#                        2019-12-09 12374       12374       1729036  P1660              4
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628             12
#
#                                                                                item_price  \
# city/province          order_date customer_id customer_id order_id product_id
# Banda Aceh/Aceh        2019-04-17 12818       12818       1642480  P1936           450000
#                        2019-11-12 12360       12360       1715116  P0758           695000
#                                                                    P3042           310000
#                        2019-12-09 12374       12374       1729036  P1660          2795000
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628           695000
#
#                                                                                total_price
# city/province          order_date customer_id customer_id order_id product_id
# Banda Aceh/Aceh        2019-04-17 12818       12818       1642480  P1936          10800000
#                        2019-11-12 12360       12360       1715116  P0758           5560000
#                                                                    P3042           3720000
#                        2019-12-09 12374       12374       1729036  P1660          11180000
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628           8340000

# %% [markdown]
# ### Slicing Data Jan 2019
# slice data hanya untuk Jan 2019

# %%
idx = pd.IndexSlice

# %%
df_jan2019 = df.loc[idx[:, "2019-01-01":"2019-01-31"], :]

# %%
df_jan2019
# Out:
#                                                                                  brand  \
# city/province          order_date customer_id customer_id order_id product_id
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628       BRAND_C
# Bandung/Jawa Barat     2019-01-09 16134       16134       1617055  P1597       BRAND_G
#                        2019-01-10 17392       17392       1617952  P2137       BRAND_M
#                        2019-01-14 15527       15527       1618828  P3115       BRAND_S
#                        2019-01-29 13253       13253       1620289  P0099       BRAND_A
# ...                                                                                ...
# Yogyakarta/Yogyakarta  2019-01-14 14062       14062       1618774  P2227       BRAND_M
#                                   14298       14298       1618762  P3638       BRAND_S
#                                   15279       15279       1618495  P1533       BRAND_G
#                                   16713       16713       1618738  P0166       BRAND_A
#                        2019-01-30 16033       16033       1620538  P2889       BRAND_R
#
#                                                                                quantity  \
# city/province          order_date customer_id customer_id order_id product_id
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628             12
# Bandung/Jawa Barat     2019-01-09 16134       16134       1617055  P1597              9
#                        2019-01-10 17392       17392       1617952  P2137              2
#                        2019-01-14 15527       15527       1618828  P3115              1
#                        2019-01-29 13253       13253       1620289  P0099             12
# ...                                                                                 ...
# Yogyakarta/Yogyakarta  2019-01-14 14062       14062       1618774  P2227             48
#                                   14298       14298       1618762  P3638             48
#                                   15279       15279       1618495  P1533              4
#                                   16713       16713       1618738  P0166              2
#                        2019-01-30 16033       16033       1620538  P2889              4
#
#                                                                                item_price  \
# city/province          order_date customer_id customer_id order_id product_id
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628           695000
# Bandung/Jawa Barat     2019-01-09 16134       16134       1617055  P1597           520000
#                        2019-01-10 17392       17392       1617952  P2137          1062000
#                        2019-01-14 15527       15527       1618828  P3115          1045000
#                        2019-01-29 13253       13253       1620289  P0099           450000
# ...                                                                                   ...
# Yogyakarta/Yogyakarta  2019-01-14 14062       14062       1618774  P2227          1745000
#                                   14298       14298       1618762  P3638            86000
#                                   15279       15279       1618495  P1533          1045000
#                                   16713       16713       1618738  P0166          1325000
#                        2019-01-30 16033       16033       1620538  P2889          2987000
#
#                                                                                total_price
# city/province          order_date customer_id customer_id order_id product_id
# Bandar Lampung/Lampung 2019-01-15 12515       12515       1619257  P0628           8340000
# Bandung/Jawa Barat     2019-01-09 16134       16134       1617055  P1597           4680000
#                        2019-01-10 17392       17392       1617952  P2137           2124000
#                        2019-01-14 15527       15527       1618828  P3115           1045000
#                        2019-01-29 13253       13253       1620289  P0099           5400000
# ...                                                                                    ...
# Yogyakarta/Yogyakarta  2019-01-14 14062       14062       1618774  P2227          83760000
#                                   14298       14298       1618762  P3638           4128000
#                                   15279       15279       1618495  P1533           4180000
#                                   16713       16713       1618738  P0166           2650000
#                        2019-01-30 16033       16033       1620538  P2889          11948000
#
# [334 rows x 4 columns]

# %% [markdown]
# Finish. Hope you enjoy it! xoxo
